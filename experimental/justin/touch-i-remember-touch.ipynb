// %%
import { getJupyterCurrentViewer } from "infra/lib/jupyterUtils.ts"

const cv = await getJupyterCurrentViewer("6c20205edf0d4d85a5d2c6f9b6cba687")
// Out:
// ↱ packages/bfDb/classes/BfCurrentViewer.ts:162
// WARN: Creating omni cv, tread carefully. Created for:  omni_person
// ↱ infra/lib/jupyterUtils.ts:34
// INFO: file:///home/runner/workspace/infra/lib/jupyterUtils.ts - impersonating google:113859313705054809643

// %%
import { BfMedia } from "packages/bfDb/models/BfMedia.ts"
const mediaId = "c9dd18cbd16f405b93cb1929ef77e8e9";
const media = await BfMedia.findX(cv, mediaId);
media.metadata.bfGid
// Out:
// "c9dd18cbd16f405b93cb1929ef77e8e9"

// %%
import { BfMediaNodeTranscript } from "packages/bfDb/models/BfMediaNodeTranscript.ts"
const transcriptId = "f9a4dfeefef3485fbfd44aad18ded5fe"
const transcript = await BfMediaNodeTranscript.findX(cv, transcriptId)
transcript.metadata.bfGid
// Out:
// "f9a4dfeefef3485fbfd44aad18ded5fe"

// %%
const mediaAncestor = await transcript.queryAncestorsByClassName(BfMedia);
mediaAncestor[0].metadata.bfGid
// Out:
// "c9dd18cbd16f405b93cb1929ef77e8e9"

// %%
transcript.props.status = "COMPLETED"
await transcript.save();
// await mediaAncestor[0].touch();
