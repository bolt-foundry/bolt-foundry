// %%
import { getJupyterCurrentViewer } from "infra/lib/jupyterUtils.ts"
const cv = await getJupyterCurrentViewer()
// Out:
// ↱ packages/bfDb/classes/BfCurrentViewer.ts:162
// WARN: Creating omni cv, tread carefully. Created for:  omni_person
// ↱ infra/lib/jupyterUtils.ts:34
// INFO: file:///home/runner/workspace/infra/lib/jupyterUtils.ts - impersonating google:113859313705054809643

// %%
import { Client } from "@replit/object-storage";
const client = new Client();

// %%
// const { ok, error } = await client.uploadFromText('file.txt', "Hello World!")
// if (!ok) {
//     console.log("Error", error);
// }

// %%
// const { ok, value, error } = await client.downloadAsText('file.txt');
// if (!ok) {
//     // ... handle the error ...
// }
// value

// %%
// const { ok, value, error } = await client.list();
// if (!ok) {
//     // ... handle the error ...
// }
// value

// %%
import { BfMediaNodeVideo } from "packages/bfDb/models/BfMediaNodeVideo.ts";
const id = "167cfe95b45542b3a53e7b9cdb2affb6";
const video = await BfMediaNodeVideo.findX(cv, id);

// %%
// const role = await video.getRole()

// %%
// role

// %%
// const { ok, value, error } = await client.exists("167cfe95b45542b3a53e7b9cdb2affb6_preview.mp4");
// value
await video.getFile();
// Out:
// "exists"

// %%
const { ok, value, error } = await client.downloadToFilename('167cfe95b45542b3a53e7b9cdb2affb6_preview.mp4', "test.mp4");
if (!ok) {
    console.log(error)
}
value
// Out:
// null
