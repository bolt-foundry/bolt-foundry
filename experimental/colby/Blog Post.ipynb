// %%
import { getRawPostData } from "lib/notionApi.ts"

// %%
const result = await getRawPostData("87674124f2814d44abeef2f01dff9e0f");
result.results
// Out:
// [
//   {
//     object: "block",
//     id: "b933fc7f-1914-400e-bfc6-88b4c55d9e81",
//     parent: {
//       type: "page_id",
//       page_id: "87674124-f281-4d44-abee-f2f01dff9e0f"
//     },
//     created_time: "2024-08-08T14:27:00.000Z",
//     last_edited_time: "2024-09-07T16:39:00.000Z",
//     created_by: { object: "user", id: "803a5db0-61e0-4409-b3a8-696c87469d0f" },
//     last_edited_by: { object: "user", id: "9fb57c8b-55bf-4630-a4a0-6b1de9041f34" },
//     has_children: false,
//     archived: false,
//     in_trash: false,
//     type: "paragraph",
//     paragraph: {
//       rich_text: [
//         {
//           type: "text",
//           text: [Object],
//           annotations: [Object],
//           plain_text: "This is a post that I’m publishing.",
//           href: null
//         },
//         {
//           type: "text",
//           text: [Object],
//           annotations: [Object],
// ...

// %%
result.results[2]
// Out:
// {
//   object: "block",
//   id: "e1bead3e-6100-4b19-9765-a24a61cf0912",
//   parent: { type: "page_id", page_id: "a1516a15-c1be-4875-a398-c288d60b4441" },
//   created_time: "2024-08-23T18:43:00.000Z",
//   last_edited_time: "2024-08-23T18:43:00.000Z",
//   created_by: { object: "user", id: "7f6c7d26-a869-475e-8518-cb7ac34a3034" },
//   last_edited_by: { object: "user", id: "7f6c7d26-a869-475e-8518-cb7ac34a3034" },
//   has_children: false,
//   archived: false,
//   in_trash: false,
//   type: "paragraph",
//   paragraph: {
//     rich_text: [
//       {
//         type: "text",
//         text: { content: "Master of His Craft", link: null },
//         annotations: {
//           bold: true,
//           italic: false,
//           strikethrough: false,
//           underline: false,
//           code: false,
//           color: "default"
//         },
//         plain_text: "Master of His Craft",
//         href: null
//       }
//     ],
//     color: "default"
//   }
// }
