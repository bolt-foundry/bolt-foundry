// %%
import { getRawPostData } from "lib/notionApi.ts"

// %%
const result = await getRawPostData("a1516a15c1be4875a398c288d60b4441");
result.results
// Out:
// [
//   {
//     object: "block",
//     id: "0ad1349c-6f7c-4973-ba8a-040bd9e7937f",
//     parent: {
//       type: "page_id",
//       page_id: "a1516a15-c1be-4875-a398-c288d60b4441"
//     },
//     created_time: "2024-08-23T18:43:00.000Z",
//     last_edited_time: "2024-08-23T18:43:00.000Z",
//     created_by: { object: "user", id: "7f6c7d26-a869-475e-8518-cb7ac34a3034" },
//     last_edited_by: { object: "user", id: "7f6c7d26-a869-475e-8518-cb7ac34a3034" },
//     has_children: false,
//     archived: false,
//     in_trash: false,
//     type: "paragraph",
//     paragraph: {
//       rich_text: [
//         {
//           type: "text",
//           text: [Object],
//           annotations: [Object],
//           plain_text: "At Bolt Foundry, a company where innovation meets precision, the development team is known for its t"... 267 more characters,
//           href: null
//         }
//       ],
//       color: "default"
//     }
//   },
//   {
//     object: "block",
// ...

// %%
result.results[2]
// Out:
// {
//   object: "block",
//   id: "e1bead3e-6100-4b19-9765-a24a61cf0912",
//   parent: { type: "page_id", page_id: "a1516a15-c1be-4875-a398-c288d60b4441" },
//   created_time: "2024-08-23T18:43:00.000Z",
//   last_edited_time: "2024-08-23T18:43:00.000Z",
//   created_by: { object: "user", id: "7f6c7d26-a869-475e-8518-cb7ac34a3034" },
//   last_edited_by: { object: "user", id: "7f6c7d26-a869-475e-8518-cb7ac34a3034" },
//   has_children: false,
//   archived: false,
//   in_trash: false,
//   type: "paragraph",
//   paragraph: {
//     rich_text: [
//       {
//         type: "text",
//         text: { content: "Master of His Craft", link: null },
//         annotations: {
//           bold: true,
//           italic: false,
//           strikethrough: false,
//           underline: false,
//           code: false,
//           color: "default"
//         },
//         plain_text: "Master of His Craft",
//         href: null
//       }
//     ],
//     color: "default"
//   }
// }
