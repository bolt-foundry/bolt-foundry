// %%
import { getRawPostData } from "lib/notionApi.ts"

// %%
const result = await getRawPostData("d70d691e729e4acab761416a0f0f4f51");
result.results
// Out:
// [
//   {
//     object: "block",
//     id: "0dc08a50-a39f-45cf-a213-5e9e9d0b01a9",
//     parent: {
//       type: "page_id",
//       page_id: "d70d691e-729e-4aca-b761-416a0f0f4f51"
//     },
//     created_time: "2024-08-19T21:46:00.000Z",
//     last_edited_time: "2024-08-20T22:49:00.000Z",
//     created_by: { object: "user", id: "7f6c7d26-a869-475e-8518-cb7ac34a3034" },
//     last_edited_by: { object: "user", id: "7f6c7d26-a869-475e-8518-cb7ac34a3034" },
//     has_children: false,
//     archived: false,
//     in_trash: false,
//     type: "image",
//     image: {
//       caption: [
//         {
//           type: "text",
//           text: [Object],
//           annotations: [Object],
//           plain_text: "Here is a caption for the image.",
//           href: null
//         }
//       ],
//       type: "file",
//       file: {
// ...

// %%
result.results[2].paragraph
// Out:
// {
//   rich_text: [
//     {
//       type: "text",
//       text: { content: "Here is some text after the image.", link: null },
//       annotations: {
//         bold: false,
//         italic: false,
//         strikethrough: false,
//         underline: false,
//         code: false,
//         color: "default"
//       },
//       plain_text: "Here is some text after the image.",
//       href: null
//     }
//   ],
//   color: "default"
// }
