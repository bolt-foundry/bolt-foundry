// %%
import { getBlogPostFromNotion } from "lib/notionApi.ts"

// %%
const result = await getBlogPostFromNotion("d70d691e729e4acab761416a0f0f4f51");
result.results
// Out:
// [
//   {
//     object: "block",
//     id: "0dc08a50-a39f-45cf-a213-5e9e9d0b01a9",
//     parent: {
//       type: "page_id",
//       page_id: "d70d691e-729e-4aca-b761-416a0f0f4f51"
//     },
//     created_time: "2024-08-19T21:46:00.000Z",
//     last_edited_time: "2024-08-19T21:47:00.000Z",
//     created_by: { object: "user", id: "7f6c7d26-a869-475e-8518-cb7ac34a3034" },
//     last_edited_by: { object: "user", id: "7f6c7d26-a869-475e-8518-cb7ac34a3034" },
//     has_children: false,
//     archived: false,
//     in_trash: false,
//     type: "image",
//     image: {
//       caption: [],
//       type: "file",
//       file: {
//         url: "https://prod-files-secure.s3.us-west-2.amazonaws.com/bf177325-d922-4ecb-926f-f1943489a78d/83a7843c-b"... 358 more characters,
//         expiry_time: "2024-08-19T23:41:16.625Z"
//       }
//     }
//   },
//   {
//     object: "block",
//     id: "fb4b902b-410d-4a3d-a5c1-f430e8c7a92c",
//     parent: {
//       type: "page_id",
// ...

// %%
let textString = "";
const paragraphText = result.results.forEach((result) => {
    result.paragraph.rich_text.forEach((array) => {
        textString += array.plain_text;
    })
})
textString
// Out:
// "This is a post that I’m publishing.  This post represents an important milestone in my journey as a "... 1395 more characters
