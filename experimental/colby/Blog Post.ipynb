// %%
import { getRawPostData } from "lib/notionApi.ts"

// %%
const result = await getRawPostData("107f9119354d807e994de00e35fe4c59");
result.results
// Out:
// [
//   {
//     object: "block",
//     id: "107f9119-354d-804c-ad54-d511b54f9203",
//     parent: {
//       type: "page_id",
//       page_id: "107f9119-354d-807e-994d-e00e35fe4c59"
//     },
//     created_time: "2024-09-20T17:38:00.000Z",
//     last_edited_time: "2024-09-20T17:39:00.000Z",
//     created_by: { object: "user", id: "7f6c7d26-a869-475e-8518-cb7ac34a3034" },
//     last_edited_by: { object: "user", id: "7f6c7d26-a869-475e-8518-cb7ac34a3034" },
//     has_children: false,
//     archived: false,
//     in_trash: false,
//     type: "heading_1",
//     heading_1: {
//       rich_text: [
//         {
//           type: "text",
//           text: [Object],
//           annotations: [Object],
//           plain_text: "Heading 1",
//           href: null
//         }
//       ],
//       is_toggleable: false,
//       color: "default"
//     }
//   },
//   {
//     object: "block",
//     id: "f48b47fe-6651-4720-a200-511867e00b95",
//     parent: {
// ...

// %%
result.results[2]
// Out:
// {
//   object: "block",
//   id: "e1bead3e-6100-4b19-9765-a24a61cf0912",
//   parent: { type: "page_id", page_id: "a1516a15-c1be-4875-a398-c288d60b4441" },
//   created_time: "2024-08-23T18:43:00.000Z",
//   last_edited_time: "2024-08-23T18:43:00.000Z",
//   created_by: { object: "user", id: "7f6c7d26-a869-475e-8518-cb7ac34a3034" },
//   last_edited_by: { object: "user", id: "7f6c7d26-a869-475e-8518-cb7ac34a3034" },
//   has_children: false,
//   archived: false,
//   in_trash: false,
//   type: "paragraph",
//   paragraph: {
//     rich_text: [
//       {
//         type: "text",
//         text: { content: "Master of His Craft", link: null },
//         annotations: {
//           bold: true,
//           italic: false,
//           strikethrough: false,
//           underline: false,
//           code: false,
//           color: "default"
//         },
//         plain_text: "Master of His Craft",
//         href: null
//       }
//     ],
//     color: "default"
//   }
// }
