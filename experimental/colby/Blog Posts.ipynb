// %%
import { getBlogPostsFromNotion, getBlogPostFromNotion, getRawDataForAllPosts } from "lib/notionApi.ts";

// %%
const data = await getBlogPostsFromNotion();
data
// Out:
// [
//   {
//     title: "Blog V0.5 Feature Test - Colby: The Best Developer at Bolt Foundry, Yet Incredibly Humble",
//     slug: "Blog-V0-5-Feature-Test-Colby-The-Best-Developer-at-Bolt-Foundry-Yet-Incredibly-Humble",
//     id: "a1516a15-c1be-4875-a398-c288d60b4441"
//   },
//   {
//     title: "How to leverage more video in your marketing plan with these 4 video types",
//     slug: "How-to-leverage-more-video-in-your-marketing-plan-with-these-4-video-types",
//     id: "551f5238-a5ab-4984-91d8-4fd780774869"
//   },
//   {
//     title: "what gear do you really need for more video for a B2B companies",
//     slug: "what-gear-do-you-really-need-for-more-video-for-a-B2B-companies",
//     id: "dd43dd2a-b797-4044-a37b-0ce2e12d843d"
//   },
//   {
//     title: "how to record videos with riverside",
//     slug: "how-to-record-videos-with-riverside",
//     id: "60b3df30-6cc2-4810-b536-c6779dc2c7aa"
//   },
//   {
//     title: "How to videos with Zoom",
// ...

// %%
const allPostData = await getRawDataForAllPosts();
allPostData
// Out:
// {
//   object: "list",
//   results: [
//     {
//       object: "page",
//       id: "a1516a15-c1be-4875-a398-c288d60b4441",
//       created_time: "2024-08-23T18:41:00.000Z",
//       last_edited_time: "2024-08-23T18:46:00.000Z",
//       created_by: { object: "user", id: "7f6c7d26-a869-475e-8518-cb7ac34a3034" },
//       last_edited_by: { object: "user", id: "7f6c7d26-a869-475e-8518-cb7ac34a3034" },
//       cover: null,
//       icon: null,
//       parent: {
//         type: "database_id",
//         database_id: "1d6117a9-a864-41f1-b339-e96346bbf0e1"
//       },
//       archived: false,
//       in_trash: false,
//       properties: {
//         Status: { id: "HLXX", type: "status", status: [Object] },
//         Author: { id: "bReU", type: "people", people: [] },
//         "Publish date": { id: "xd%60~", type: "date", date: null },
//         Name: { id: "title", type: "title", title: [Array] }
//       },
// ...

// %%
allPostData.results[0].properties
// Out:
// {
//   Status: {
//     id: "HLXX",
//     type: "status",
//     status: {
//       id: "83d02878-0274-437e-944b-f4416ba232f4",
//       name: "Idea",
//       color: "default"
//     }
//   },
//   Author: { id: "bReU", type: "people", people: [] },
//   "Publish date": { id: "xd%60~", type: "date", date: null },
//   Name: {
//     id: "title",
//     type: "title",
//     title: [
//       {
//         type: "text",
//         text: {
//           content: "Blog V0.5 Feature Test - Colby: The Best Developer at Bolt Foundry, Yet Incredibly Humble",
//           link: null
//         },
//         annotations: {
//           bold: false,
//           italic: false,
//           strikethrough: false,
//           underline: false,
//           code: false,
//           color: "default"
//         },
//         plain_text: "Blog V0.5 Feature Test - Colby: The Best Developer at Bolt Foundry, Yet Incredibly Humble",
//         href: null
//       }
//     ]
//   }
// }
