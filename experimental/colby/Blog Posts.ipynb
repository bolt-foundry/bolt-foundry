// %%
import { getBlogPostsFromNotion, getBlogPostFromNotion } from "lib/notionApi.ts";

// %%
const data = await getBlogPostsFromNotion();
data
// Out:
// [
//   { title: "Image Test", slug: "Image-Test" },
//   { title: "My New Row", slug: "My-New-Row" },
//   { title: "Unpublished post", slug: "Unpublished-post" },
//   { title: "Example post headline", slug: "Example-post-headline" }
// ]
