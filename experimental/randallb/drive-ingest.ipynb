// %%
import { getJupyterCurrentViewer } from "infra/lib/jupyterUtils.ts";

const cv = await getJupyterCurrentViewer();
cv
// Out:
// /home/runner/randallb-08-15/infra/lib/jupyterUtils.ts - INFO:  file:///home/runner/randallb-08-15/infra/lib/jupyterUtils.ts - impersonating google:108810509077746991108
// BfCurrentViewerFromAccount {
//   organizationBfGid: "bf_internal_org",
//   role: "OWNER",
//   personBfGid: "google:108810509077746991108",
//   accountBfGid: "7157a7e194cf4c0b9f3f3a6a23716ff2",
//   creator: "file:///home/runner/randallb-08-15/infra/lib/jupyterUtils.ts",
//   jwtPayload: null,
//   __typename: "BfCurrentViewerFromAccount"
// }

// %%
import { BfGoogleDriveResource } from "packages/bfDb/models/BfGoogleDriveResource.ts";
const folders = await BfGoogleDriveResource.query(
  cv,
  { bfOid: cv.bfOid },
  {},
);
const folder = folders[0]
folder
// Out:
// BfGoogleDriveResource {
//   currentViewer: BfCurrentViewerFromAccount {
//     organizationBfGid: "bf_internal_org",
//     role: "OWNER",
//     personBfGid: "google:108810509077746991108",
//     accountBfGid: "7157a7e194cf4c0b9f3f3a6a23716ff2",
//     creator: "file:///home/runner/randallb-08-15/infra/lib/jupyterUtils.ts",
//     jwtPayload: null,
//     __typename: "BfCurrentViewerFromAccount"
//   },
//   serverProps: {
//     name: "⚡ Bolt Foundry Files ⚡",
//     resourceId: "1UXWJhvOMPoFRyeUPX6m_eMraPmYg4M-0"
//   },
//   clientProps: {},
//   metadata: {
//     bfCid: "7157a7e194cf4c0b9f3f3a6a23716ff2",
//     bfGid: "1UXWJhvOMPoFRyeUPX6m_eMraPmYg4M-0",
//     bfOid: "bf_internal_org",
//     sortValue: "1723811046333",
//     className: "BfGoogleDriveResource",
//     createdAt: 2024-08-16T12:24:06.187Z,
//     lastUpdated: 2024-08-16T12:24:06.187Z,
//     bfSid: null,
//     bfTid: null,
//     bfTClassName: null,
//     bfSClassName: null
//   },
//   _cachedProps: undefined
// }

// %%
import { createFolder, fetchFolderContents, fetchMetadata } from "lib/googleDriveApi.ts";
const folderAccessToken = await folder.getAccessToken()
// Out:
// /home/runner/randallb-08-15/packages/bfDb/models/BfGoogleDriveResource.ts - DEBUG:  getting access token for folder 1UXWJhvOMPoFRyeUPX6m_eMraPmYg4M-0 1UXWJhvOMPoFRyeUPX6m_eMraPmYg4M-0
// /home/runner/randallb-08-15/packages/bfDb/models/BfGoogleDriveResource.ts - DEBUG:  got bfGoogleAuths [
//   BfGoogleAuth {
//     currentViewer: BfCurrentViewerFromAccount {
//       organizationBfGid: "bf_internal_org",
//       role: "OWNER",
//       personBfGid: "google:108810509077746991108",
//       accountBfGid: "7157a7e194cf4c0b9f3f3a6a23716ff2",
//       creator: "file:///home/runner/randallb-08-15/infra/lib/jupyterUtils.ts",
//       jwtPayload: null,
//       __typename: "BfCurrentViewerFromAccount"
//     },
//     serverProps: {
//       refreshToken: "1//05bC173CKyKlDCgYIARAAGAUSNwF-L9IrG0aEzQSThvpViCSvZJp_tRAeCtFu78w2vfM4W2SYtjRFw9YJTftt2L5A2RGQmu4j"... 3 more characters
//     },
//     clientProps: {},
//     metadata: {
//       bfCid: "6e58d1bdd60a49368e524f44616b60b4",
//       bfGid: "a9b0d7e4f7484ad6a48842667a45d9fe",
//       bfOid: "bf_internal_org",
//       sortValue: "1723737315456",
//       className: "BfGoogleAuth",
//       createdAt: 2024-08-15T15:55:15.456Z,
//       lastUpdated: 2024-08-15T15:55:15.456Z,
//       bfSid: null,
//       bfTid: null,
//       bfTClassName: null,
//       bfSClassName: null
//     },
//     _cachedProps: undefined
//   }
// ]
// /home/runner/randallb-08-15/packages/bfDb/models/BfGoogleDriveResource.ts - DEBUG:  got googleAuth BfGoogleAuth {
//   currentViewer: BfCurrentViewerFromAccount {
//     organizationBfGid: "bf_internal_org",
//     role: "OWNER",
//     personBfGid: "google:108810509077746991108",
//     accountBfGid: "7157a7e194cf4c0b9f3f3a6a23716ff2",
//     creator: "file:///home/runner/randallb-08-15/infra/lib/jupyterUtils.ts",
//     jwtPayload: null,
//     __typename: "BfCurrentViewerFromAccount"
//   },
//   serverProps: {
//     refreshToken: "1//05bC173CKyKlDCgYIARAAGAUSNwF-L9IrG0aEzQSThvpViCSvZJp_tRAeCtFu78w2vfM4W2SYtjRFw9YJTftt2L5A2RGQmu4j"... 3 more characters
//   },
//   clientProps: {},
//   metadata: {
//     bfCid: "6e58d1bdd60a49368e524f44616b60b4",
//     bfGid: "a9b0d7e4f7484ad6a48842667a45d9fe",
//     bfOid: "bf_internal_org",
//     sortValue: "1723737315456",
//     className: "BfGoogleAuth",
//     createdAt: 2024-08-15T15:55:15.456Z,
//     lastUpdated: 2024-08-15T15:55:15.456Z,
//     bfSid: null,
//     bfTid: null,
//     bfTClassName: null,
//     bfSClassName: null
//   },
//   _cachedProps: undefined
// }

// %%
import { BfGoogleAuth } from "packages/bfDb/models/BfGoogleAuth.ts";
import { BfEdge } from "packages/bfDb/coreModels/BfEdge.ts";
