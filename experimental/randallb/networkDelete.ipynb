// %%
import { getJupyterCurrentViewer } from "infra/lib/jupyterUtils.ts";
// const cv = await getJupyterCurrentViewer("1be6f899487e45c98f06cd0224e957df");
Deno.env.set("BF_ENV", "TEST")

// %%
await import("./BfNode_test.ts")
// Out:
// BfNode - Create and retrieve a node ... ok (130ms)
// BfNode - Create a target node and edge ... ok (332ms)
// BfNode - Query target instances ... ok (526ms)
// BfNode - Delete node and associated edges ...↱ packages/bfDb/coreModels/BfEdge.ts:305
// INFO: BfEdge#0402277fdbe24461b6c72b9905da46a9 is the last remaining edge to BfNode#9cb7cf15e3c84573908f15a0d1cc4ad3 so deleting the node.
//  ok (506ms)
// BfNode - Deep network delete with multiple generations ...INFO: BfEdge#9976fe45c32b498dbe73fa24cd1aeccf is the last remaining edge to BfNode#182e6b8b43864fd59f648b761781a655 so deleting the node.
// INFO: BfEdge#df16bd40a94a46af9b03026d0a71c036 is the last remaining edge to BfNode#de0e1e478a6946b091a12b4f2f52d390 so deleting the node.
// INFO: BfEdge#3fbc10b7dbaf466bbf4fda56f91b9be5 is the last remaining edge to BfNode#80320ce30d2746969ac6e71d036e343f so deleting the node.
// INFO: BfEdge#d3faaedeb9e34afbba85f052c9b6472b is the last remaining edge to BfNode#2cd1d8a1ea7649048cd04669a23a9d0d so deleting the node.
// INFO: BfEdge#a18e3c8fecd04030afb666a91c9f4c6a is the last remaining edge to BfNode#a058339d99e241b2b011fdeefc113c1a so deleting the node.
//  ok (1s)
// BfNode - Deep network delete with multiple sources ...↱ packages/bfDb/coreModels/BfEdge.ts:313
// INFO: More than one edge to BfNode#9dcf446147cb42688671ccc1b105c14a so deleting BfEdge#4516f5585e914553a7bd73aef1463349 without deleting the other
// ↱ packages/bfDb/coreModels/BfEdge.ts:305
// INFO: BfEdge#8b43671b48ec4cc7b99cf26d691e5dcf is the last remaining edge to BfNode#9dcf446147cb42688671ccc1b105c14a so deleting the node.
// INFO: BfEdge#5b8d840932d6461b8531a7fcc54af1f5 is the last remaining edge to BfNode#3d023273343e48d78830dbbc06c403fd so deleting the node.
// INFO: BfEdge#e59e6db7037a49dda4497da275681b86 is the last remaining edge to BfNode#127121c13dc44ff0a13918aca34d5171 so deleting the node.
//  ok (1s)
//
// ok | 6 passed | 0 failed (4s)
// [Module: null prototype] {  }
