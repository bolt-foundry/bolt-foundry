// %%
import { getJupyterCurrentViewer } from "infra/lib/jupyterUtils.ts";
// const cv = await getJupyterCurrentViewer("1be6f899487e45c98f06cd0224e957df");
Deno.env.set("BF_ENV", "TEST")

// %%
await import("packages/bfDb/coreModels/__tests__/BfNode_test.disabled.ts")
// Out:
// BfNode - Create and retrieve a node ... ok (222ms)
// BfNode - Create a target node and edge ... ok (489ms)
// BfNode - Query target instances ... ok (824ms)
// BfNode - Delete node and associated edges ...
// ↱ packages/bfDb/bfDb.ts:698
// ERROR: Error: No item found with bfOid: test-org and bfGid: 50ccf9a4e0434d09b59b7a6384ce67d9
//     at bfDeleteItem (file:///home/runner/workspace/packages/bfDb/bfDb.ts:692:13)
//     at eventLoopTick (ext:core/01_core.js:175:7)
//     at async BfNode.delete (file:///home/runner/workspace/packages/bfDb/classes/BfModel.ts:453:7)
//     at async BfNode.delete (file:///home/runner/workspace/packages/bfDb/coreModels/BfNode.ts:234:5)
//     at async file:///home/runner/workspace/packages/bfDb/coreModels/__tests__/BfNode_test.disabled.ts:94:3
//     at async innerWrapped (ext:cli/40_test.js:191:5)
//     at async exitSanitizer (ext:cli/40_test.js:107:27)
//     at async outerWrapped (ext:cli/40_test.js:134:14)
//  FAILED (460ms)
// ...
