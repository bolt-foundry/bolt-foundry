// %%
import { getJupyterCurrentViewer } from "infra/lib/jupyterUtils.ts";
// const cv = await getJupyterCurrentViewer("1be6f899487e45c98f06cd0224e957df");
Deno.env.set("BF_ENV", "TEST")

// %%
await import("./BfNode_test_.ts")
// Out:
// BfNode - Create and retrieve a node ... ok (172ms)
// BfNode - Create a target node and edge ... ok (303ms)
// BfNode - Query target instances ... ok (567ms)
// BfNode - Delete node and associated edges ...↱ packages/bfDb/coreModels/BfEdge.ts:305
// INFO: BfEdge#a74d6f1ef8674d60b767bc55ff32de55 is the last remaining edge to BfNode#56b8d5562a2544cb9b366092841f8efb so deleting the node.
//  ok (537ms)
// BfNode - Deep network delete with multiple generations ...INFO: BfEdge#3976e411cafb4e72b224e6923d8df2ad is the last remaining edge to BfNode#5d10c699d3de41be8e343138ea36d8bf so deleting the node.
// INFO: BfEdge#9f077eab810a446bba458f5ca4cd77bd is the last remaining edge to BfNode#f421f381dfc4413899af7b6e46433373 so deleting the node.
// INFO: BfEdge#a137fa8002b3493fac6ec8fac2de4898 is the last remaining edge to BfNode#7d12195776ca40e3ad4045ae27a1cc82 so deleting the node.
// INFO: BfEdge#9570a6f33fab41c9bcfed917fa123fa3 is the last remaining edge to BfNode#847741faa0904dbc92c535c4e4496ac1 so deleting the node.
// INFO: BfEdge#de9c809c70f14926abcefa9fa1aad398 is the last remaining edge to BfNode#a6986aa032694e6eb2a5fb0975e52834 so deleting the node.
//  ok (1s)
// BfNode - Deep network delete with multiple sources ...↱ packages/bfDb/coreModels/BfEdge.ts:313
// INFO: More than one edge to BfNode#e098ddf4550c4587a9e1a334b53b8ab9 so deleting BfEdge#92785d40decf4ebeb1c27948e2fce94c without deleting the other
// ↱ packages/bfDb/coreModels/BfEdge.ts:305
// INFO: BfEdge#6990f263c3fb4a86b022c5f60d9c657f is the last remaining edge to BfNode#e098ddf4550c4587a9e1a334b53b8ab9 so deleting the node.
// INFO: BfEdge#ce1949257dbc4daa9b962d4a66e3657f is the last remaining edge to BfNode#fd5a9d23193f43d584d8692bfc7b2b72 so deleting the node.
// INFO: BfEdge#aa9655c4f0754b5fa80af0bc3688a639 is the last remaining edge to BfNode#c27d1b8f68e54d9583968d0640d0141d so deleting the node.
//  ok (1s)
//
// ok | 6 passed | 0 failed (4s)
// [Module: null prototype] {  }
