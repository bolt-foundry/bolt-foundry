// %%
import { getJupyterCurrentViewer } from "infra/lib/jupyterUtils.ts"
const cv = await getJupyterCurrentViewer()
cv
// Out:
// Stack trace:
// Error: No account row for JUPYTER_BFACCOUNT_BFGID
//     at getJupyterCurrentViewer (file:///home/runner/randallb-09-05-1/infra/lib/jupyterUtils.ts:26:11)
//     at eventLoopTick (ext:core/01_core.js:168:7)
//     at async <anonymous>:2:12
