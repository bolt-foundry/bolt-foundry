// %%
import { getJupyterCurrentViewer } from "infra/lib/jupyterUtils.ts"
const cv = await getJupyterCurrentViewer()
cv
// Out:
// /home/runner/user-refresh-token-stuff/infra/lib/jupyterUtils.ts - INFO:  file:///home/runner/user-refresh-token-stuff/infra/lib/jupyterUtils.ts - impersonating google:108810509077746991108
// BfCurrentViewerFromAccount {
//   organizationBfGid: "bf_internal_org",
//   role: "MEMBER",
//   personBfGid: "google:108810509077746991108",
//   accountBfGid: "ecfb8bb0e91f41efafae6df021baf40c",
//   creator: "file:///home/runner/user-refresh-token-stuff/infra/lib/jupyterUtils.ts",
//   jwtPayload: null,
//   __typename: "BfCurrentViewerFromAccount"
// }

// %%
const rt = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..dfc4e0yzcioEsP1gEOV5GQvgG06rCLrp0glWIa8uOSg"
rt
// Out:
// "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..dfc4e0yzcioEsP1gEOV5GQvgG06rCLrp0glWIa8uOSg"

// %%
import { BfAccount } from "packages/bfDb/models/BfAccount.ts"
await BfAccount.getRefreshedAccessToken(rt)
// Out:
// Stack trace:
// Error: Your role (ANON) does not have permission to READ on BfPerson.
//     at BfPerson.validatePermissions (file:///home/runner/user-refresh-token-stuff/packages/bfDb/classes/BfModel.ts:397:11)
//     at BfPerson.load (file:///home/runner/user-refresh-token-stuff/packages/bfDb/classes/BfModel.ts:414:16)
//     at async Function.findX (file:///home/runner/user-refresh-token-stuff/packages/bfDb/classes/BfModel.ts:150:7)
//     at async Function.getRefreshedAccessToken (file:///home/runner/user-refresh-token-stuff/packages/bfDb/models/BfAccount.ts:77:20)
//     at async <anonymous>:2:1

// %%
import { BfCurrentViewerAccessToken } from "packages/bfDb/classes/BfCurrentViewer.ts";
const importMeta = {};
const currentViewer = await BfCurrentViewerAccessToken.create(
      importMeta,
      rt,
    );
currentViewer
// Out:
// BfCurrentViewerAccessToken {
//   organizationBfGid: "bf_internal_org",
//   role: "REFRESH_CREDENTIALS_ONLY",
//   personBfGid: "google:108810509077746991108",
//   accountBfGid: "ecfb8bb0e91f41efafae6df021baf40c",
//   creator: undefined,
//   jwtPayload: {
//     role: "REFRESH_CREDENTIALS_ONLY",
//     organizationBfGid: "bf_internal_org",
//     personBfGid: "google:108810509077746991108",
//     accountBfGid: "ecfb8bb0e91f41efafae6df021baf40c",
//     sub: "bf_internal_org",
//     iat: 1725558387,
//     iss: "ecfb8bb0e91f41efafae6df021baf40c",
//     exp: 1728150387,
//     aud: "bfBff"
//   },
//   __typename: "BfCurrentViewerAccessToken"
// }

// %%
import { BfPerson } from "packages/bfDb/models/BfPerson.ts"
const person = await BfPerson.findX(
      currentViewer,
      currentViewer.personBfGid,
    );
person
// Out:
// BfPerson {
//   currentViewer: BfCurrentViewerAccessToken {
//     organizationBfGid: "bf_internal_org",
//     role: "REFRESH_CREDENTIALS_ONLY",
//     personBfGid: "google:108810509077746991108",
//     accountBfGid: "ecfb8bb0e91f41efafae6df021baf40c",
//     creator: undefined,
//     jwtPayload: {
//       role: "REFRESH_CREDENTIALS_ONLY",
//       organizationBfGid: "bf_internal_org",
//       personBfGid: "google:108810509077746991108",
//       accountBfGid: "ecfb8bb0e91f41efafae6df021baf40c",
//       sub: "bf_internal_org",
//       iat: 1725558387,
//       iss: "ecfb8bb0e91f41efafae6df021baf40c",
//       exp: 1728150387,
//       aud: "bfBff"
//     },
//     __typename: "BfCurrentViewerAccessToken"
//   },
//   serverProps: { name: "Randall Bennett", email: "randall@boltfoundry.com" },
//   clientProps: undefined,
//   metadata: {
//     bfGid: "google:108810509077746991108",
//     bfSid: null,
//     bfTid: null,
//     bfOid: "google:108810509077746991108",
// ...

// %%
import { bfGetItem } from "packages/bfDb/bfDb.ts"

await bfGetItem(currentViewer.organizationBfGid, currentViewer.accountBfGid)
const thing = [currentViewer.organizationBfGid, currentViewer.accountBfGid]
thing
// Out:
// [ "bf_internal_org", "ecfb8bb0e91f41efafae6df021baf40c" ]

// %%
await person.querySourcesForClass(BfAccount)
// Out:
// []

// %%
import { BfEdge } from "packages/bfDb/coreModels/BfEdge.ts"

// %%
const rt = ""
rt

// %%
import { BfAccount } from "packages/bfDb/models/BfAccount.ts"
await BfAccount.getRefreshedAccessToken(rt)
// Out:
// Stack trace:
// Error: Your role (ANON) does not have permission to READ on BfPerson.
//     at BfPerson.validatePermissions (file:///home/runner/user-refresh-token-stuff/packages/bfDb/classes/BfModel.ts:397:11)
//     at BfPerson.load (file:///home/runner/user-refresh-token-stuff/packages/bfDb/classes/BfModel.ts:414:16)
//     at async Function.findX (file:///home/runner/user-refresh-token-stuff/packages/bfDb/classes/BfModel.ts:150:7)
//     at async Function.getRefreshedAccessToken (file:///home/runner/user-refresh-token-stuff/packages/bfDb/models/BfAccount.ts:77:20)
//     at async <anonymous>:2:1

// %%
import { BfCurrentViewerAccessToken } from "packages/bfDb/classes/BfCurrentViewer.ts";
const importMeta = {};
const currentViewer = await BfCurrentViewerAccessToken.create(
      importMeta,
      rt,
    );
currentViewer
// Out:
// BfCurrentViewerAccessToken {
//   organizationBfGid: "bf_internal_org",
//   role: "REFRESH_CREDENTIALS_ONLY",
//   personBfGid: "google:108810509077746991108",
//   accountBfGid: "ecfb8bb0e91f41efafae6df021baf40c",
//   creator: undefined,
//   jwtPayload: {
//     role: "REFRESH_CREDENTIALS_ONLY",
//     organizationBfGid: "bf_internal_org",
//     personBfGid: "google:108810509077746991108",
//     accountBfGid: "ecfb8bb0e91f41efafae6df021baf40c",
//     sub: "bf_internal_org",
//     iat: 1725558387,
//     iss: "ecfb8bb0e91f41efafae6df021baf40c",
//     exp: 1728150387,
//     aud: "bfBff"
//   },
//   __typename: "BfCurrentViewerAccessToken"
// }

// %%
import { BfPerson } from "packages/bfDb/models/BfPerson.ts"
const person = await BfPerson.findX(
      currentViewer,
      currentViewer.personBfGid,
    );
person
// Out:
// BfPerson {
//   currentViewer: BfCurrentViewerAccessToken {
//     organizationBfGid: "bf_internal_org",
//     role: "REFRESH_CREDENTIALS_ONLY",
//     personBfGid: "google:108810509077746991108",
//     accountBfGid: "ecfb8bb0e91f41efafae6df021baf40c",
//     creator: undefined,
//     jwtPayload: {
//       role: "REFRESH_CREDENTIALS_ONLY",
//       organizationBfGid: "bf_internal_org",
//       personBfGid: "google:108810509077746991108",
//       accountBfGid: "ecfb8bb0e91f41efafae6df021baf40c",
//       sub: "bf_internal_org",
//       iat: 1725558387,
//       iss: "ecfb8bb0e91f41efafae6df021baf40c",
//       exp: 1728150387,
//       aud: "bfBff"
//     },
//     __typename: "BfCurrentViewerAccessToken"
//   },
//   serverProps: { name: "Randall Bennett", email: "randall@boltfoundry.com" },
//   clientProps: undefined,
//   metadata: {
//     bfGid: "google:108810509077746991108",
//     bfSid: null,
//     bfTid: null,
//     bfOid: "google:108810509077746991108",
// ...

// %%
import { bfGetItem } from "packages/bfDb/bfDb.ts"

await bfGetItem(currentViewer.organizationBfGid, currentViewer.accountBfGid)
const thing = [currentViewer.organizationBfGid, currentViewer.accountBfGid]
thing
// Out:
// [ "bf_internal_org", "ecfb8bb0e91f41efafae6df021baf40c" ]

// %%
await person.querySourcesForClass(BfAccount)
// Out:
// []

// %%
import { BfEdge } from "packages/bfDb/coreModels/BfEdge.ts"
