// %%
import { getJupyterCurrentViewer } from "infra/lib/jupyterUtils.ts";
const cv = await getJupyterCurrentViewer("cb59666a451d45a6b9bfec3ae55cadee");
if (!cv) throw new Error();
import { getLogger } from "deps.ts";
// const logger = getLogger("jupyter");
// Out:
// packages/bfDb/classes/BfCurrentViewer.ts - WARN:  Creating omni cv, tread carefully. Created for:  omni_person
// infra/lib/jupyterUtils.ts - INFO:  file:///home/runner/workspace/infra/lib/jupyterUtils.ts - impersonating google:108810509077746991108

// %% [markdown]
// # Search organization
//
// Organizations have a collection. Watch folders add stuff to a collection. A savedSearch can ask a collection for results. The collection does the job of figuring out what to search (pinecone) and then talking to the AI to perform the search. It then updates a callback (savedsearch receive search result method?) and then that actually displays to the UI.

// %% [markdown]
// ## BfCollection

// %% [markdown]
// ## Mutation to create
//
// Initially, we'll create the collection and the resource at the same time.

// %%
import { BfOrganization } from "packages/bfDb/models/BfOrganization.ts";
import { BfCurrentViewer } from "packages/bfDb/classes/BfCurrentViewer.ts";
import { BfCollection } from "packages/bfDb/models/BfCollection.ts";

async function createCollectionMutation(
  bfCurrentViewer: BfCurrentViewer,
  name: string,
  googleDriveResourceFolderId: string,
) {
  const org = await BfOrganization.findForCurrentViewer(bfCurrentViewer);
  const collection = await org.createTargetNode(BfCollection, {
    name,
  });
  const watchedFolder = await collection.addWatchedFolder(
    googleDriveResourceFolderId,
  );
  // return collection.toGraphql();
  return collection;
}

// %% [markdown]
// ## BFF command to reset

// %%
import { cleanModels } from "packages/bfDb/utils.ts";

async function resetCollection(dryRun = false) {
  await cleanModels(
    ["BfMedia", "BfGoogleDriveResource", "BfCollection", "BfSavedSearch", "BfSavedSearchResult"],
    dryRun,
  );
}

// %% [markdown]
// ## Create version for RB
//
// this is the "bloomtech ai" folder in "internal" shared drive.

// %%
const folderId = "1sq4gNo6pZ89xiu9hGD11o6z_9uoMI1Ka";
const name = "default"

// await resetCollection()
// const collection = await createCollectionMutation(cv, name, folderId);

// %% [markdown]
// ## Search mutation example

// %%
const folderId = "1sq4gNo6pZ89xiu9hGD11o6z_9uoMI1Ka";
const name = "default"

// const collection = await createCollectionMutation(cv, name, folderId);

const collection = await BfCollection.findX(cv, "593507b35085485f91edcf30145d9553")

// %%
import { BfSavedSearchResult } from "packages/bfDb/models/BfSavedSearchResult.ts";
import { BfSavedSearch } from "packages/bfDb/models/BfSavedSearch.ts";
const collection = await BfCollection.findX(cv, "771271c1f8af41b1b5cd033a713ed4e2");
const query = "docker";
// Out:
// Stack trace:
// Error: Could not load BfCollection with bfOid: bf_internal_org bfGid: 771271c1f8af41b1b5cd033a713ed4e2
//     at BfCollection.load (file:///home/runner/workspace/packages/bfDb/classes/BfModel.ts:375:15)
//     at eventLoopTick (ext:core/01_core.js:175:7)
//     at async Function.findX (file:///home/runner/workspace/packages/bfDb/classes/BfModel.ts:145:7)
//     at async <anonymous>:3:20

// %%
// const savedSearch = await collection.createSavedSearch(query);
const savedSearch = await BfSavedSearch.findX(cv, "bb808d6dc46b4150ae96de15cbe62190")

// %%
const id = savedSearch.metadata.bfGid

// %%
import { cleanModels } from "packages/bfDb/utils.ts"

// await cleanModels(["BfCollection", "BfMedia", "BfGoogleDriveResource"], false)

// %%
const results = await savedSearch.queryTargetsConnectionForGraphQL(BfSavedSearchResult, {})
results.count
// Out:
// packages/bfDb/coreModels/BfEdge.ts - DEBUG:  queryTargetsConnectionForGraphQL [class BfSavedSearchResult extends BfNode] bb808d6dc46b4150ae96de15cbe62190
// packages/bfDb/coreModels/BfEdge.ts - DEBUG:  connection {
//   pageInfo: {
//     startCursor: "MTcyNzQ1MjEzNjk3Nw==",
//     endCursor: "MTcyNzQ1MjEzNzYwNg==",
//     hasNextPage: false,
//     hasPreviousPage: false
//   },
//   count: 273,
//   edges: [
//     {
//       cursor: "MTcyNzQ1MjEzNjk3Nw==",
//       node: { id: "b504fe7003224f5ebeb0e7beb984b898", __typename: "BfEdge" }
//     },
//     {
//       cursor: "MTcyNzQ1MjEzNjk3OA==",
//       node: { id: "d8c22d00953040eaa58b601c11e7f6a4", __typename: "BfEdge" }
//     },
//     {
//       cursor: "MTcyNzQ1MjEzNzA2MA==",
//       node: { id: "53c66992de314336a97003d57e5a9f6b", __typename: "BfEdge" }
//     },
//     {
//       cursor: "MTcyNzQ1MjEzNzA2MQ==",
//       node: { id: "ba25f8f5e99f4ef8a83d4ec72ff11e6c", __typename: "BfEdge" }
//     },
//     {
//       cursor: "MTcyNzQ1MjEzNzUzOA==",
//       node: { id: "ce2c7e9d20db4b0fb241b81b7c765f7b", __typename: "BfEdge" }
//     },
//     {
//       cursor: "MTcyNzQ1MjEzNzU0OA==",
//       node: { id: "49a5a53cecb34b658bdb0befe32091c6", __typename: "BfEdge" }
//     },
//     {
//       cursor: "MTcyNzQ1MjEzNzU4Mw==",
//       node: { id: "ba563232c91e4bd99e7e31ab65965b3f", __typename: "BfEdge" }
//     },
//     {
//       cursor: "MTcyNzQ1MjEzNzU5Mw==",
//       node: { id: "305b7c6858354467bb5f55d27b3f3e3e", __typename: "BfEdge" }
//     },
//     {
//       cursor: "MTcyNzQ1MjEzNzYwNg==",
//       node: { id: "159323dc92a54d48be814cb3a4d384ae", __typename: "BfEdge" }
//     },
//     {
//       cursor: "MTcyNzQ1MjEzNzYwNg==",
//       node: { id: "95867a40b62e474e95760ab392205a19", __typename: "BfEdge" }
//     }
//   ]
// }
// packages/bfDb/coreModels/BfEdge.ts - DEBUG:  targetEdgeIds [
//   "b504fe7003224f5ebeb0e7beb984b898",
//   "d8c22d00953040eaa58b601c11e7f6a4",
//   "53c66992de314336a97003d57e5a9f6b",
//   "ba25f8f5e99f4ef8a83d4ec72ff11e6c",
//   "ce2c7e9d20db4b0fb241b81b7c765f7b",
//   "49a5a53cecb34b658bdb0befe32091c6",
//   "ba563232c91e4bd99e7e31ab65965b3f",
//   "305b7c6858354467bb5f55d27b3f3e3e",
//   "159323dc92a54d48be814cb3a4d384ae",
//   "95867a40b62e474e95760ab392205a19"
// ]
// packages/bfDb/coreModels/BfEdge.ts - DEBUG:  targetIds [
//   "2546c4ee64724eff9045e63154c4dc8a",
//   "ac622c08d5f840f4bb18526db224c209",
//   "bdd413feaad0447f9036ca28fca9448d",
//   "b4faffbee7334f6988979c7839c757ac",
//   "ded4b7c0dcaf400190cd7a3f639de63d",
//   "71452539a325449b8ebd011fecb6154b",
//   "18137da70c544d8f8019c62f52ef6bfd",
//   "e625196422cd4ffcbd1a19bac48435d4",
//   "4287de42a1b043be9aab337c9e1b64cd",
//   "aa764d68b5e44b989bb648abb6ce22a2"
// ]
// packages/bfDb/coreModels/BfEdge.ts - DEBUG:  targetConnection {
//   pageInfo: {
//     startCursor: "MTcyNzQ1MjEzNjkzMA==",
//     endCursor: "MTcyNzQ1MjEzNzUzMg==",
//     hasNextPage: false,
//     hasPreviousPage: false
//   },
//   count: 4708,
//   edges: [
//     {
//       cursor: "MTcyNzQ1MjEzNjkzMA==",
//       node: {
//         body: "Oh no, it really isn't. Like, I'm not going to lie. Like, my first day, my first day, tools were built on, like, I don't remember what it was either. It was. It was one of the AWS. Essentially I just ran virtual machines from AWS to. That's what I sold to my clients.",
//         title: "Docker and AWS Infrastructure",
//         topics: "Docker, AWS infrastructure, virtual machines",
//         rationale: "The excerpt mentions using AWS infrastructure and virtual machines, which are often associated with Docker containers for deployment and management.",
//         confidence: 0.8,
//         description: "Discussion about using AWS infrastructure and virtual machines for clients",
//         id: "bdd413feaad0447f9036ca28fca9448d",
//         __typename: "BfSavedSearchResult"
//       }
//     },
//     {
//       cursor: "MTcyNzQ1MjEzNjkzMQ==",
//       node: {
//         body: "Ash had asked me if I would teach a class on fully aimed at open source. I do know how to up to deploying models on EC instances. And AWS is.",
//         title: "Deploying Models on EC Instances",
//         topics: "Docker, deploying models, EC instances, AWS",
//         rationale: "The excerpt specifically mentions deploying models on EC instances in AWS, which can involve using Docker containers for deployment.",
//         confidence: 0.7,
//         description: "Reference to deploying models on EC instances in AWS",
//         id: "2546c4ee64724eff9045e63154c4dc8a",
//         __typename: "BfSavedSearchResult"
//       }
//     },
//     {
//       cursor: "MTcyNzQ1MjEzNjk5NA==",
//       node: {
//         body: "Function calling is specifically going to referring to like when you're calling one specific, like one single function, and it's actually like how it's built on how it was originally built by OpenAI. Last year, tool calling as OpenAI company essentially changed how it referred to function calling, back to tool calling.",
//         title: "Tool Calling and Function Calling",
//         topics: "Tool Calling, Function Calling",
//         rationale: "The excerpt directly discusses the difference between function calling and tool calling, providing context on how OpenAI changed the terminology.",
//         confidence: 0.9,
//         description: "Explanation of the difference between function calling and tool calling",
//         id: "ac622c08d5f840f4bb18526db224c209",
//         __typename: "BfSavedSearchResult"
//       }
//     },
//     {
//       cursor: "MTcyNzQ1MjEzNjk5NQ==",
//       node: {
//         body: "Tool calling, multiple functions, function calling generally referring to one single function. So we're going to be able to configure our models to recommend whether it's working with multiple functions or just a single function with like one little bit of a step by step operation.",
//         title: "Tool Calling and Function Calling",
//         topics: "Tool Calling, Function Calling",
//         rationale: "The excerpt provides a clear distinction between tool calling and function calling, emphasizing the ability to work with multiple functions in tool calling.",
//         confidence: 0.85,
//         description: "Clarification on tool calling and function calling",
//         id: "b4faffbee7334f6988979c7839c757ac",
//         __typename: "BfSavedSearchResult"
//       }
//     },
//     {
//       cursor: "MTcyNzQ1MjEzNzMyMQ==",
//       node: {
//         body: "So if you have questions, shout them out. Yeah, I have a question. So this tool calling operation is really to be able to take in a prompt or a query like this and to tell you based on the context of that prompt, okay, you should invoke this function with these parameters, essentially. Yes. Okay. Yes.",
//         title: "Tool Calling Operations",
//         topics: "tool calling operations, function invocation, prompts, queries",
//         rationale: "The excerpt directly discusses tool calling operations and how they function to invoke functions based on prompts or queries, which is relevant to the concept of using tools like Docker.",
//         confidence: 0.9,
//         description: "Discussion about tool calling operations and how they work to invoke functions based on prompts or queries.",
//         id: "e625196422cd4ffcbd1a19bac48435d4",
//         __typename: "BfSavedSearchResult"
//       }
//     },
//     {
//       cursor: "MTcyNzQ1MjEzNzMyMQ==",
//       node: {
//         body: "I promised you a video, so I just want to show that the video I just shared on the Slack channel is the LangChain announcement of their tool calling operations. And it's pretty cool because it's nice to see that they.",
//         title: "LangChain Announcement",
//         topics: "LangChain, tool calling operations, announcement, video",
//         rationale: "The excerpt mentions a video about LangChain's tool calling operations announcement, which is related to the concept of using tools like Docker.",
//         confidence: 0.8,
//         description: "Reference to a video about LangChain's tool calling operations announcement.",
//         id: "4287de42a1b043be9aab337c9e1b64cd",
//         __typename: "BfSavedSearchResult"
//       }
//     },
//     {
//       cursor: "MTcyNzQ1MjEzNzQ4Mw==",
//       node: {
//         body: "Oh no, it really isn't. Like, I'm not going to lie. Like, my first day, my first day, tools were built on, like, I don't remember what it was either. It was. It was one of the AWS. Essentially I just ran virtual machines from AWS to. That's what I sold to my clients.",
//         title: "Docker and AWS Infrastructure",
//         topics: "Docker, AWS infrastructure, virtual machines",
//         rationale: "The excerpt mentions using AWS infrastructure and virtual machines, which are commonly associated with Docker containers and deployment.",
//         confidence: 0.8,
//         description: "Discussion about using AWS infrastructure and virtual machines for clients",
//         id: "aa764d68b5e44b989bb648abb6ce22a2",
//         __typename: "BfSavedSearchResult"
//       }
//     },
//     {
//       cursor: "MTcyNzQ1MjEzNzQ4Mw==",
//       node: {
//         body: "I do know how to up to deploying models on EC instances. And AWS is. I don't know much about GCP or Azure, but I do work with AWs a lot.",
//         title: "Deploying Models on EC Instances",
//         topics: "Docker, deploying models, EC instances, AWS",
//         rationale: "The excerpt discusses deploying models on EC instances in AWS, which can involve using Docker containers for deployment.",
//         confidence: 0.7,
//         description: "Experience with deploying models on EC instances in AWS",
//         id: "ded4b7c0dcaf400190cd7a3f639de63d",
//         __typename: "BfSavedSearchResult"
//       }
//     },
//     {
//       cursor: "MTcyNzQ1MjEzNzUzMQ==",
//       node: {
//         body: "So if you have questions, shout them out. Yeah, I have a question. So this tool calling operation is really to be able to take in a prompt or a query like this and to tell you based on the context of that prompt, okay, you should invoke this function with these parameters, essentially. Yes. Okay. Yes.",
//         title: "Tool Calling Operations",
//         topics: "tool calling operations, invoking functions, prompts, context",
//         rationale: "The excerpt directly discusses tool calling operations and how functions are invoked based on prompts and context, which is relevant to the concept of using tools like Docker.",
//         confidence: 0.9,
//         description: "Discussion about tool calling operations and invoking functions based on prompts and context.",
//         id: "71452539a325449b8ebd011fecb6154b",
//         __typename: "BfSavedSearchResult"
//       }
//     },
//     {
//       cursor: "MTcyNzQ1MjEzNzUzMg==",
//       node: {
//         body: "I promised you a video, so I just want to show that the video I just shared on the Slack channel is the LangChain announcement of their tool calling operations. And it's pretty cool because it's nice to see that they.",
//         title: "LangChain Announcement",
//         topics: "LangChain, tool calling operations, announcement, video",
//         rationale: "The excerpt mentions a video about LangChain's tool calling operations announcement, which is related to the concept of using tools like Docker.",
//         confidence: 0.8,
//         description: "Reference to a video about LangChain's tool calling operations announcement.",
//         id: "18137da70c544d8f8019c62f52ef6bfd",
//         __typename: "BfSavedSearchResult"
//       }
//     }
//   ]
// }
// 273

// %%
const result = await BfSavedSearchResult.findX(cv, "2546c4ee64724eff9045e63154c4dc8a")
import { BfMediaNodeTranscript } from "packages/bfDb/models/BfMediaNodeTranscript.ts";
const transcripts = await result.querySourceInstances(BfMediaNodeTranscript, {})
const transcript = transcripts[0];
// Out:
// packages/bfDb/coreModels/BfEdge.ts - DEBUG:  querySources [class BfMediaNodeTranscript extends BfNode] 2546c4ee64724eff9045e63154c4dc8a
// packages/bfDb/coreModels/BfEdge.ts - DEBUG:  sourceEdges [
//   BfEdge {
//     currentViewer: BfCurrentViewerFromAccount {
//       organizationBfGid: "bf_internal_org",
//       role: "MEMBER",
//       personBfGid: "google:108810509077746991108",
//       accountBfGid: "cb59666a451d45a6b9bfec3ae55cadee",
//       creator: "file:///home/runner/workspace/infra/lib/jupyterUtils.ts",
//       jwtPayload: null,
//       __typename: "BfCurrentViewerFromAccount"
//     },
//     serverProps: {},
//     clientProps: {},
//     metadata: {
//       bfCid: "cb59666a451d45a6b9bfec3ae55cadee",
//       bfGid: "87c2826b91e44cca83b1bdd3e9edfaa4",
//     personBfGid: "google:108810509077746991108",
//     accountBfGid: "cb59666a451d45a6b9bfec3ae55cadee",
//     creator: "file:///home/runner/workspace/infra/lib/jupyterUtils.ts",
//     jwtPayload: null,
//     __typename: "BfCurrentViewerFromAccount"
//   },
//   serverProps: {
//     words: [
//       {
//         end: 8312,
//         text: "Okay,",
//         start: 7840,
//         speaker: "A",
//         confidence: 0.71921
//       },
//       {
//         end: 9050,
//         text: "folks,",
//         start: 8326,
//         speaker: "A",
//         confidence: 0.86407
//       },
//       {
//         end: 10086,
//         text: "this",
//         start: 9510,
//         speaker: "A",
//         confidence: 0.99886
//       },
//       {
//         end: 10850,
//         text: "is",
//         start: 10198,
//         speaker: "A",
//         confidence: 0.99201
//       },
//       {
//         end: 12086,
//         text: "pretty",
//         start: 11750,
//         speaker: "A",
//         confidence: 0.96513
//       },
//       {
//         end: 12510,
//         text: "straightforward",
//         start: 12118,
//         speaker: "A",
//         confidence: 0.80535
//       },
//       {
//         end: 13130,
//         text: "class.",
//         start: 12550,
//         speaker: "A",
//         confidence: 0.99826
//       },
//       {
//         end: 15542,
//         text: "Notice",
//         start: 15150,
//         speaker: "A",
//         confidence: 0.99278
//       },
//       {
//         end: 15654,
//         text: "a",
//         start: 15566,
//         speaker: "A",
//         confidence: 1
//       },
//       {
//         end: 15782,
//         text: "few",
//         start: 15662,
//         speaker: "A",
//         confidence: 0.99995
//       },
//       {
//         end: 16014,
//         text: "folks",
//         start: 15806,
//         speaker: "A",
//         confidence: 0.82372
//       },
//       {
//         end: 16222,
//         text: "coming",
//         start: 16062,
//         speaker: "A",
//         confidence: 0.99387
//       },
//       {
//         end: 16334,
//         text: "in,",
//         start: 16246,
//         speaker: "A",
//         confidence: 0.98626
//       },
//       {
//         end: 16438,
//         text: "so",
//         start: 16342,
//         speaker: "A",
//         confidence: 0.9545
//       },
//       {
//         end: 16558,
//         text: "I'll",
//         start: 16454,
//         speaker: "A",
//         confidence: 0.96601
//       },
//       {
//         end: 16702,
//         text: "keep",
//         start: 16574,
//         speaker: "A",
//         confidence: 0.9999
//       },
//       {
//         end: 16886,
//         text: "an",
//         start: 16726,
//         speaker: "A",
//         confidence: 0.9997
//       },
//       {
//         end: 17062,
//         text: "eye",
//         start: 16918,
//         speaker: "A",
//         confidence: 0.99991
//       },
//       {
//         end: 17222,
//         text: "on",
//         start: 17086,
//         speaker: "A",
//         confidence: 0.99961
//       },
//       {
//         end: 17790,
//         text: "the",
//         start: 17246,
//         speaker: "A",
//         confidence: 0.99
//       },
//       {
//         end: 18246,
//         text: "room",
//         start: 17950,
//         speaker: "A",
//         confidence: 0.99887
//       },
//       {
//         end: 18470,
//         text: "as",
//         start: 18278,
//         speaker: "A",
//         confidence: 0.99765
//       },
//       {
//         end: 18806,
//         text: "more",
//         start: 18510,
//         speaker: "A",
//         confidence: 0.98626
//       },
//       {
//         end: 19334,
//         text: "folks",
//         start: 18878,
//         speaker: "A",
//         confidence: 0.96857
//       },
//       {
//         end: 20262,
//         text: "arrive.",
//         start: 19422,
//         speaker: "A",
//         confidence: 0.68886
//       },
//       {
//         end: 20742,

//         speaker: "A",
//         confidence: 1
//       },
//       {
//         end: 45710,
//         text: "today's",
//         start: 45334,
//         speaker: "A",
//         confidence: 0.94161
//       },
//       {
//         end: 45966,
//         text: "lesson",
//         start: 45750,
//         speaker: "A",
//         confidence: 0.99947
//       },
//       {
//         end: 46166,
//         text: "where",
//         start: 45998,
//         speaker: "A",
//         confidence: 0.99958
//       },
//       {
//         end: 46406,
//         text: "it's",
//         start: 46198,
//         speaker: "A",
//         confidence: 0.98207
//       },
//       {
//         end: 46558,
//         text: "a",
//         start: 46438,
//         speaker: "A",
//         confidence: 1
//       },
//       {
//         end: 46750,
//         text: "lot",
//         start: 46574,
//         speaker: "A",
//         confidence: 0.99988
//       },
//       {
//         end: 47370,
//         text: "less",
//         start: 46790,
//         speaker: "A",
//         confidence: 0.99876
//       },
//       {
//         end: 48206,
//         text: "coding",
//         start: 47750,
//         speaker: "A",
//         confidence: 0.8743
//       },
//       {
//         end: 48710,
//         text: "necessarily,",
//         start: 48238,
//         speaker: "A",
//         confidence: 0.99745
//       },
//       {
//         end: 49070,
//         text: "but",
//         start: 48750,
//         speaker: "A",
//         confidence: 0.99603
//       },
//       {
//         end: 49318,
//         text: "you",
//         start: 49150,
//         speaker: "A",
//         confidence: 0.88692
//       },
//       ... 13573 more items
//     ],
//     status: "COMPLETED",
//     ingestionPct: 0.999987455702951,
//     transcriptionPct: 1
//   },
//   clientProps: {},
//   metadata: {
//     bfCid: "cb59666a451d45a6b9bfec3ae55cadee",
//     bfGid: "6fd6b2ac0812428d893ff99c8d95ca95",
//     bfOid: "bf_internal_org",
//     sortValue: "1727450943139",
//     className: "BfMediaNodeTranscript",
//     createdAt: 2024-09-27T15:29:03.139Z,
//     lastUpdated: 2024-09-27T15:49:45.700Z,
//     bfSid: null,
//     bfTid: null,
//     bfTClassName: null,
//     bfSClassName: null
//   },
//   _cachedProps: undefined
// }

// %%
const text = result.props.body;
const timecodedWords = transcript.getTimecodesForText(text)

// %%
console.log(text)
console.log(timecodedWords.words.map((word) => word.text).join(" "))
timecodedWords
// Out:
// Ash had asked me if I would teach a class on fully aimed at open source. I do know how to up to deploying models on EC instances. And AWS is.
// Ash had asked me if I would teach a class on fully aimed at open source. I do know how to up to deploying models on EC instances. And AWS is.
// {
//   duration: 12696,
//   start: 3611044,
//   end: 3623740,
//   words: [
//     {
//       end: 3611372,
//       text: "Ash",
//       start: 3611044,
//       speaker: "B",
//       confidence: 0.73408
//     },
//     {
//       end: 3611532,
//       text: "had",
//       start: 3611396,
//       speaker: "B",
//       confidence: 0.89765
//     },
//     {
//       end: 3611764,
//       text: "asked",
//       start: 3611556,
//       speaker: "B",
//       confidence: 0.89078
//     },
//     {
//       end: 3611972,
//       text: "me",
//       start: 3611812,
//       speaker: "B",
//       confidence: 0.99804
//     },
//     {
//       end: 3612132,
//       text: "if",
