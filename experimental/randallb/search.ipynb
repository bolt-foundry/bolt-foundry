// %%
import { getJupyterCurrentViewer } from "infra/lib/jupyterUtils.ts";
import { BfOrganization } from "packages/bfDb/models/BfOrganization.ts";
import { BfMedia } from "packages/bfDb/models/BfMedia.ts";

const cv = await getJupyterCurrentViewer()
const currentOrg = await BfOrganization.findX(cv, cv.organizationBfGid);
const bfMedias = await currentOrg.queryTargetInstances(BfMedia)
// Out:
// /home/runner/randallb-09-10-1/packages/bfDb/classes/BfCurrentViewer.ts - WARN:  Creating omni cv, tread carefully. Created for:  omni_person
// /home/runner/randallb-09-10-1/infra/lib/jupyterUtils.ts - INFO:  file:///home/runner/randallb-09-10-1/infra/lib/jupyterUtils.ts - impersonating google:108810509077746991108
// /home/runner/randallb-09-10-1/packages/bfDb/coreModels/BfEdge.ts - DEBUG:  queryTargets [class BfMedia extends BfNode] bf_internal_org
// /home/runner/randallb-09-10-1/packages/bfDb/coreModels/BfEdge.ts - DEBUG:  targetEdges [
//   BfEdge {
//     currentViewer: BfCurrentViewerFromAccount {
//       organizationBfGid: "bf_internal_org",
//       role: "MEMBER",
//       personBfGid: "google:108810509077746991108",
//       accountBfGid: "94fd74dc63ba4e3b86ac3bacc98a52ba",
//       creator: "file:///home/runner/randallb-09-10-1/infra/lib/jupyterUtils.ts",
//       jwtPayload: null,
//       __typename: "BfCurrentViewerFromAccount"
//     },
//     serverProps: {},
//     clientProps: {},
//     metadata: {
//       bfCid: "94fd74dc63ba4e3b86ac3bacc98a52ba",
//       bfGid: "dd58cbf552e54e65b3b1bd0fd33c13c6",
//       bfOid: "bf_internal_org",
//       sortValue: "1726084201855",
//       className: "BfEdge",
//       createdAt: 2024-09-11T19:50:01.855Z,
//       lastUpdated: 2024-09-11T19:50:01.855Z,
//       bfSid: "bf_internal_org",
//       bfTid: "e9b83c04adbc4b668b36646709a9d907",
//       bfTClassName: "BfMedia",
//       bfSClassName: "BfOrganization"
//     },
//     _cachedProps: undefined,
//     __typename: "BfEdge"
//   }
// ]
// /home/runner/randallb-09-10-1/packages/bfDb/coreModels/BfEdge.ts - DEBUG:  targetEdgeIds [ "e9b83c04adbc4b668b36646709a9d907" ]
// /home/runner/randallb-09-10-1/packages/bfDb/coreModels/BfEdge.ts - DEBUG:  targets [
//   BfMedia {
//     currentViewer: BfCurrentViewerFromAccount {
//       organizationBfGid: "bf_internal_org",
//       role: "MEMBER",
//       personBfGid: "google:108810509077746991108",
//       accountBfGid: "94fd74dc63ba4e3b86ac3bacc98a52ba",
//       creator: "file:///home/runner/randallb-09-10-1/infra/lib/jupyterUtils.ts",
//       jwtPayload: null,
//       __typename: "BfCurrentViewerFromAccount"
//     },
//     serverProps: {},
//     clientProps: {},
//     metadata: {
//       bfCid: "94fd74dc63ba4e3b86ac3bacc98a52ba",
//       bfGid: "e9b83c04adbc4b668b36646709a9d907",
//       bfOid: "bf_internal_org",
//       sortValue: "1726084201561",
//       className: "BfMedia",
//       createdAt: 2024-09-11T19:50:01.561Z,
//       lastUpdated: 2024-09-11T19:50:01.561Z,
//       bfSid: null,
//       bfTid: null,
//       bfTClassName: null,
//       bfSClassName: null
//     },
//     _cachedProps: undefined
//   }
// ]
