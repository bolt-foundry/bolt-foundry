// %%
import { getJupyterCurrentViewer } from "infra/lib/jupyterUtils.ts";
const cv = await getJupyterCurrentViewer("fb0dcb5eb70744f98fd079c4c1d262cd");
if (!cv) throw new Error();
import { getLogger } from "deps.ts";
const logger = getLogger("jupyter");
// Out:
// packages/bfDb/classes/BfCurrentViewer.ts - WARN:  Creating omni cv, tread carefully. Created for:  omni_person
// infra/lib/jupyterUtils.ts - INFO:  file:///home/runner/workspace/infra/lib/jupyterUtils.ts - impersonating google:108810509077746991108

// %% [markdown]
// # Search organization
//
// Organizations have a collection. Watch folders add stuff to a collection. A savedSearch can ask a collection for results. The collection does the job of figuring out what to search (pinecone) and then talking to the AI to perform the search. It then updates a callback (savedsearch receive search result method?) and then that actually displays to the UI.

// %% [markdown]
// ## BfCollection

// %% [markdown]
// ## Mutation to create
//
// Initially, we'll create the collection and the resource at the same time.

// %%
import { BfOrganization } from "packages/bfDb/models/BfOrganization.ts";
import { BfCurrentViewer } from "packages/bfDb/classes/BfCurrentViewer.ts";
import { BfCollection } from "packages/bfDb/models/BfCollection.ts";

async function createCollectionMutation(
  bfCurrentViewer: BfCurrentViewer,
  name: string,
  googleDriveResourceFolderId: string,
) {
  const org = await BfOrganization.findForCurrentViewer(bfCurrentViewer);
  const collection = await org.createTargetNode(BfCollection, {
    name,
  });
  const watchedFolder = await collection.addWatchedFolder(
    googleDriveResourceFolderId,
  );
  // return collection.toGraphql();
  return collection;
}

// %% [markdown]
// ## BFF command to reset

// %%
import { cleanModels } from "packages/bfDb/utils.ts";

async function resetCollection(dryRun = false) {
  await cleanModels(
    ["BfMedia", "BfGoogleDriveResource", "BfCollection", "BfSavedSearch", "BfSavedSearchResult"],
    dryRun,
  );
}

// %% [markdown]
// ## Create version for RB
//
// this is the "bloomtech ai" folder in "internal" shared drive.

// %%
const folderId = "1sq4gNo6pZ89xiu9hGD11o6z_9uoMI1Ka";
const name = "default"

// await resetCollection()
// const collection = await createCollectionMutation(cv, name, folderId);

// %% [markdown]
// ## Search mutation example

// %%
import { BfSavedSearchResult } from "packages/bfDb/models/BfSavedSearchResult.ts";
import { BfSavedSearch } from "packages/bfDb/models/BfSavedSearch.ts";
const collection = await BfCollection.findX(cv, "9bcde7f411a94b70abbab4b67352090a");
const query = "docker";
// const savedSearch = await collection.createSavedSearch(query);
const savedSearch = await BfSavedSearch.findX(cv, "720b521701bb41ada51c277d4b0dd245")

// %%
const id = savedSearch.metadata.bfGid

// %%
import { BfSavedSearchResult } from "packages/bfDb/models/BfSavedSearchResult.ts";
import { BfSavedSearch } from "packages/bfDb/models/BfSavedSearch.ts";
const savedSearch = await BfSavedSearch.findX(cv, id)
const results = await savedSearch.queryTargetsConnectionForGraphQL(BfSavedSearchResult, {});
// Out:
// packages/bfDb/coreModels/BfEdge.ts - DEBUG:  queryTargetsConnectionForGraphQL [class BfSavedSearchResult extends BfNode] 720b521701bb41ada51c277d4b0dd245
// packages/bfDb/bfDb.ts - DEBUG:  {
//   metadata: {
//     bfSid: "720b521701bb41ada51c277d4b0dd245",
//     bfTClassName: "BfSavedSearchResult",
//     bfOid: "bf_internal_org"
//   },
//   props: {},
//   connectionArgs: {}
// }
// packages/bfDb/bfDb.ts - DEBUG:  {
//   metadataToQuery: {
//     bfSid: "720b521701bb41ada51c277d4b0dd245",
//     bfTClassName: "BfSavedSearchResult",
//     bfOid: "bf_internal_org"
//   },
//   propsToQuery: {},
//   bfGids: [],
//   orderDirection: "ASC",
//   orderBy: "sort_value",
//   useSizeLimit: false,
//   cursorValue: undefined,
//   maxSizeBytes: 10485760,
//   batchSize: 4
// }
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 0
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 4
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 8
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 12
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 16
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 20
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 24
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 28
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 32
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 36
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 40
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 44
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 48
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 52
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 56
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 60
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 64
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 68
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 72
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 76
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 80
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 84
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 88
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 92
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 96
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 100
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 104
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 108
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 112
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 116
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 120
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 124
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 128
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 132
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 136
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 140
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 144
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 148
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 152
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 156
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 160
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 164
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 168
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 172
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 176
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 180
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 184
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 188
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 192
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 196
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 200
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 204
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 208
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  {
//   metadataToQuery: {
//     bfSid: "720b521701bb41ada51c277d4b0dd245",
//     bfTClassName: "BfSavedSearchResult",
//     bfOid: "bf_internal_org"
//   },
//   propsToQuery: {},
//   bfGids: [],
//   orderDirection: "ASC",
//   orderBy: "sort_value",
//   useSizeLimit: false,
//   cursorValue: undefined,
//   maxSizeBytes: 10485760,
//   batchSize: 4
// }
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 0
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 4
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 8
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 12
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 16
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 20
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 24
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 28
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 32
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 36
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 40
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 44
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]
// packages/bfDb/bfDb.ts - DEBUG:  Executing query
//       SELECT *
//       FROM bfdb
//       WHERE bf_sid = $1 AND bf_t_class_name = $2 AND bf_oid = $3 AND 1=1 AND 1=1
//       ORDER BY sort_value ASC
//       LIMIT 4 OFFSET 48
//      [
//   "720b521701bb41ada51c277d4b0dd245",
//   "BfSavedSearchResult",
//   "bf_internal_org"
// ]

// %%
id
