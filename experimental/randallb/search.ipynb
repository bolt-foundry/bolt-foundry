// %%
import { getJupyterCurrentViewer } from "infra/lib/jupyterUtils.ts";
const cv = await getJupyterCurrentViewer("1431a931f0d34aa38fbb62258f59cc6b");
if (!cv) throw new Error();
import { getLogger } from "deps.ts";
const logger = getLogger("jupyter");
// Out:
// packages/bfDb/classes/BfCurrentViewer.ts - WARN:  Creating omni cv, tread carefully. Created for:  omni_person
// infra/lib/jupyterUtils.ts - INFO:  file:///home/runner/workspace/infra/lib/jupyterUtils.ts - impersonating google:108810509077746991108

// %% [markdown]
// # Search organization
//
// Organizations have a collection. Watch folders add stuff to a collection. A savedSearch can ask a collection for results. The collection does the job of figuring out what to search (pinecone) and then talking to the AI to perform the search. It then updates a callback (savedsearch receive search result method?) and then that actually displays to the UI.

// %% [markdown]
// ## BfCollection

// %% [markdown]
// ## Mutation to create
//
// Initially, we'll create the collection and the resource at the same time.

// %%
import { BfOrganization } from "packages/bfDb/models/BfOrganization.ts";
import { BfCurrentViewer } from "packages/bfDb/classes/BfCurrentViewer.ts";
import { BfCollection } from "packages/bfDb/models/BfCollection.ts";

async function createCollectionMutation(
  bfCurrentViewer: BfCurrentViewer,
  name: string,
  googleDriveResourceFolderId: string,
) {
  const org = await BfOrganization.findForCurrentViewer(bfCurrentViewer);
  const collection = await org.createTargetNode(BfCollection, {
    name,
  });
  const watchedFolder = await collection.addWatchedFolder(
    googleDriveResourceFolderId,
  );
  // return collection.toGraphql();
  return collection;
}

// %% [markdown]
// ## BFF command to reset

// %%
import { cleanModels } from "packages/bfDb/utils.ts";

async function resetCollection(dryRun = false) {
  await cleanModels(
    ["BfMedia", "BfGoogleDriveResource", "BfCollection", "BfSavedSearch", "BfSavedSearchResult"],
    dryRun,
  );
}

// %% [markdown]
// ## Create version for RB
//
// this is the "bloomtech ai" folder in "internal" shared drive.

// %%
const folderId = "1sq4gNo6pZ89xiu9hGD11o6z_9uoMI1Ka";
const name = "default"

await resetCollection()
const collection = await createCollectionMutation(cv, name, folderId);
// Out:
// packages/bfDb/utils.ts - WARN:  Removing 'BfMedia', 'BfGoogleDriveResource', 'BfCollection', 'BfSavedSearch', 'BfSavedSearchResult' model classes from 0 nodes and edges
// packages/bfDb/utils.ts - WARN:  Removed 'BfMedia', 'BfGoogleDriveResource', 'BfCollection', 'BfSavedSearch', 'BfSavedSearchResult' model classes from nodes and edges
// packages/bfDb/models/BfCollection.ts - INFO:  Adding watch folder 1sq4gNo6pZ89xiu9hGD11o6z_9uoMI1Ka to BfCollection#7fdc91dfced3462faa4de1c0eb9908d5
// Stack trace:
// Error: no google auth
//     at BfGoogleDriveResource.afterCreate (file:///home/runner/workspace/packages/bfDb/models/BfGoogleDriveResource.ts:48:28)
//     at eventLoopTick (ext:core/01_core.js:175:7)
//     at async Function.__DANGEROUS__createUnattached (file:///home/runner/workspace/packages/bfDb/classes/BfModel.ts:92:5)
//     at async BfCollection.createTargetNode (file:///home/runner/workspace/packages/bfDb/coreModels/BfNode.ts:107:25)
//     at async BfCollection.addWatchedFolder (file:///home/runner/workspace/packages/bfDb/models/BfCollection.ts:34:11)
//     at async createCollectionMutation (<anonymous>:9:25)
//     at async <anonymous>:4:20

// %% [markdown]
// ## Search mutation example

// %%
const folderId = "1sq4gNo6pZ89xiu9hGD11o6z_9uoMI1Ka";
const name = "default"

// const collection = await createCollectionMutation(cv, name, folderId);
const collection = await BfCollection.findX(cv, "213e81d17eb74db5b6f995bd7c3dd5f6")
// Out:
// packages/bfDb/models/BfCollection.ts - INFO:  Adding watch folder 1sq4gNo6pZ89xiu9hGD11o6z_9uoMI1Ka to BfCollection#dd18ca8acec149c3b094a839fc36e2be

// %%
import { BfSavedSearchResult } from "packages/bfDb/models/BfSavedSearchResult.ts";
import { BfSavedSearch } from "packages/bfDb/models/BfSavedSearch.ts";
const collection = await BfCollection.findX(cv, "7bf4d0cedf1440ebb2474ed0def9da37");
const query = "docker";
// const savedSearch = await collection.createSavedSearch(query);
const savedSearch = await BfSavedSearch.findX(cv, "720b521701bb41ada51c277d4b0dd245")
// Out:
// Stack trace:
// Error: Could not load BfCollection with bfOid: bf_internal_org bfGid: 9bcde7f411a94b70abbab4b67352090a
//     at BfCollection.load (file:///home/runner/workspace/packages/bfDb/classes/BfModel.ts:374:15)
//     at eventLoopTick (ext:core/01_core.js:175:7)
//     at async Function.findX (file:///home/runner/workspace/packages/bfDb/classes/BfModel.ts:144:7)
//     at async <anonymous>:3:20

// %%
const id = savedSearch.metadata.bfGid
// Out:
// Stack trace:
// ReferenceError: savedSearch is not defined
//     at <anonymous>:1:33

// %%
collection
// Out:
// BfCollection {
//   currentViewer: BfCurrentViewerFromAccount {
//     organizationBfGid: "bf_internal_org",
//     role: "MEMBER",
//     personBfGid: "google:108810509077746991108",
//     accountBfGid: "32d22c74b1f348cbabf8809098723ad2",
//     creator: "file:///home/runner/workspace/infra/lib/jupyterUtils.ts",
//     jwtPayload: null,
//     __typename: "BfCurrentViewerFromAccount"
//   },
//   serverProps: { name: "default" },
//   clientProps: { name: "default" },
//   metadata: {
//     bfGid: "dd18ca8acec149c3b094a839fc36e2be",
//     bfSid: null,
//     bfTid: null,
//     bfOid: "bf_internal_org",
//     bfCid: "32d22c74b1f348cbabf8809098723ad2",
//     bfTClassName: null,
//     bfSClassName: null,
//     className: "BfCollection",
//     createdAt: 2024-09-25T20:32:51.702Z,
//     lastUpdated: 2024-09-25T20:32:56.358Z
//   },
//   _cachedProps: { name: "default" }
// }

// %%
import { cleanModels } from "packages/bfDb/utils.ts"

// await cleanModels(["BfCollection", "BfMedia", "BfGoogleDriveResource"], false)
// Out:
// packages/bfDb/utils.ts - WARN:  Removing 'BfCollection', 'BfMedia', 'BfGoogleDriveResource' model classes from 0 nodes and edges
// packages/bfDb/utils.ts - WARN:  Removed 'BfCollection', 'BfMedia', 'BfGoogleDriveResource' model classes from nodes and edges
